# %%
using StatsPlots
using Plots.PlotMeasures

# %%
using Pkg

# %%
Pkg.status("StatsPlots")
# Out:
# Status `~/.julia/environments/v1.5/Project.toml`
#   [f3b207a7] StatsPlots v0.14.9 `https://github.com/JuliaPlots/StatsPlots.jl#master`

# %%
ctg = repeat(["A", "B", "C" ], outer = 3)
nam1 = repeat(["a", "b", "c"], inner = 3)
data =[54.8 132.4 2280; 498.0 1_456.8 4_8028.0; 1_901.2 7_547.8 477_082.0]
# Out:
# 3×3 Array{Float64,2}:
#    54.8   132.4    2280.0
#   498.0  1456.8   48028.0
#  1901.2  7547.8  477082.0

# %%
groupedbar(nam1, data, group=ctg, yscale=:log10, fillto=1e-2, xlabel = "size", legendfontsize = 14, size=(800,600), tickfont = (14, :black), guidefontsize=14, ylabel = "cpu time / s", lw = 0, legend=:topleft, top_margin = 5mm)

# %%
data=[10 12; 1 1; 0.25 0.25]
# Out:
# 3×2 Array{Float64,2}:
#  10.0   12.0
#   1.0    1.0
#   0.25   0.25

# %%
nam = repeat(["a", "b"], inner = 3)
ctg = repeat(["A", "B", "C" ], outer = 2)
# Out:
# 6-element Array{String,1}:
#  "A"
#  "B"
#  "C"
#  "A"
#  "B"
#  "C"

# %%
groupedbar(nam, data, group=ctg, xlabel = "size", legendfontsize = 14, size=(800,600), tickfont = (14, :black), guidefontsize=14, ylabel = "cpu time / s", lw = 0, legend=:topright, top_margin = 5mm)

# %%
groupedbar(nam, data, yscale=:log10, group=ctg, xlabel = "size", legendfontsize = 14, size=(800,600), tickfont = (14, :black), guidefontsize=14, ylabel = "cpu time / s", lw = 0, legend=:topright, top_margin = 5mm)
